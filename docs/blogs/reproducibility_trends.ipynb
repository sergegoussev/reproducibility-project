# %% [raw]
# ---
# title: Trends in reproducibility in price statistics
# date: 2025-11-12
# author: Serge Goussev
# execute:
#   echo: false
# format:
#   html:
#     toc: true
#     toc-expand: 2
#     code-fold: true
#     code-summary: "Show the code"
#     code-tools: true
# categories:
#   - reproducibility
# ---

# %% [markdown]
# This blog will go over what the trends in reproducibility in price statistics are over the last decade or so.
